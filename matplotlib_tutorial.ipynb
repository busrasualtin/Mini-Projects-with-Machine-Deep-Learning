# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# **Temel Cizim İslemleri**

# %% [markdown]
# Plot y versus x as lines and/or markers. plot(*args[,scale_x,scale_y,data])

# %%
plt.plot([1,2,3,4],[1,4,9,16])

# %%
x=[1,2,3,4]
y=[1,4,9,16]
plt.plot(x,y)
plt.show()    # bu fonksiyon grafigin uzerinde cikan mesaji silecektir

# %%
plt.title("First Graph")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.plot(x,y)
plt.show()

# %%
# x ye y eksenlerindeki sayisal degerlerin düzenini biz ayarlayabiliyoruz

plt.xticks([1,2,3,4])
plt.yticks([1,4,9,16])
plt.title("First Graph")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.plot(x,y)
plt.show()

# %% [markdown]
# **Lejant Koyma**

# %%
# buradaki fark label="x^2" ayıracını ve plt.legend() kullanmak
# grafigin sag/sol ust kosesinde olusacak olan ifade icin kullanilir
plt.plot(x,y,label="x^2",color="green")
plt.xticks([1,2,3,4])
plt.yticks([1,4,9,16])
plt.title("First Graph")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.legend()
plt.show()

# %%
# cizginin stiliyle oynamak icin

plt.plot(x,y,label="x^2",color="red", linewidth=2, linestyle='--', marker=".")
plt.xticks([0,1,2,3,4,5])
plt.yticks([0,1,4,9,16,25])
plt.title("First Graph")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.legend()
plt.show()

# %% [markdown]
# **Ayni Grafikte Birden Fazla Cizim Yapmak**

# %%
plt.plot(x,y,label="x^2",color="red", linewidth=2, linestyle='--', marker=".")
plt.xticks([0,1,2,3,4,5])
plt.yticks([0,1,4,9,16,25])
plt.title("First Graph")
plt.xlabel("x-axis")
plt.ylabel("y-axis")

# ikinci cizim
x2=np.arange(0,5,0.5)
plt.plot(x2,x2*2,color="blue",linewidth=2, marker=".",label="2*x")

plt.legend()
plt.show()

# %% [markdown]
# **Grafigi Bilgisayara Kaydetme**

# %%
plt.plot(x,y,label="x^2",color="red", linewidth=2, linestyle='--', marker=".")
plt.xticks([0,1,2,3,4,5])
plt.yticks([0,1,4,9,16,25])
plt.title("First Graph")
plt.xlabel("x-axis")
plt.ylabel("y-axis")

# ikinci cizim
x2=np.arange(0,5,0.5)
plt.plot(x2,x2*2,color="blue",linewidth=2, marker=".",label="2*x")

plt.legend()
plt.savefig("firstgraph.png",dpi=300)
plt.show()

# %% [markdown]
# **Barchart**

# %%
x=["Ankara","Istanbul","Izmir"]
y=[120,178,87]

plt.bar(x,y)
plt.show()

# %%
# eger barlardan birini farklı stille gorsellemek istiyorsak
bars=plt.bar(x,y)
bars[1].set_hatch("/")
bars[0].set_hatch(".")
plt.show()

# %% [markdown]
# **Ornekler**

# %%
gas=pd.read_csv("petrolfiyatlari.csv")
gas
# Out:
#     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0   1990        NaN    1.77    3.62     2.65   4.59   3.16    1.00
# 1   1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2   1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3   1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4   1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
# 5   1995       1.95    1.53    4.26     3.96   4.00   4.43    1.11
# 6   1996       2.12    1.61    4.41     3.94   4.39   3.64    1.25
# 7   1997       2.05    1.62    4.00     3.53   4.07   3.26    1.47
# 8   1998       1.63    1.38    3.87     3.34   3.84   2.82    1.49
# 9   1999       1.72    1.52    3.85     3.42   3.87   3.27    1.79
# 10  2000       1.94    1.86    3.80     3.45   3.77   3.65    2.01
# 11  2001       1.71    1.72    3.51     3.40   3.57   3.27    2.20
# 12  2002       1.76    1.69    3.62     3.67   3.74   3.15    2.24
# ...

# %%
plt.title("Petrol Fiyatları")
plt.plot(gas["Year"],gas["USA"],"b-",label="USA")

plt.xlabel("Yıl")
plt.ylabel("Dolar")

plt.legend()
plt.show()

# "b-" anlami cizgi seklinde blue olarak goster demek

# %%
plt.title("Petrol Fiyatları")
plt.plot(gas.Year, gas.USA, "b-", label="USA")
plt.plot(gas.Year, gas.Canada, "r-", label="Canada")
plt.plot(gas.Year, gas["South Korea"], "g.-", label="South Korea")
plt.plot(gas.Year, gas.France, "y.-", label="France")

plt.xlabel("Yıl")
plt.ylabel("Dolar")

plt.legend()
plt.show()

# South Korea icin arada bosluk oldugundan dolayı köseli parantez yazim seklini uyguluyoruz.
# Diger ulkeler icin tek kelime isimlendirmeden dolayı nokta yazım sekliyle kullanabiliyoruz.

# %% [markdown]
# **Figure Size**

# %%
plt.figure(figsize=(18,7))
plt.title("Petrol Fiyatları")
plt.plot(gas.Year, gas.USA, "b-", label="USA")
plt.plot(gas.Year, gas.Canada, "r-", label="Canada")
plt.plot(gas.Year, gas["South Korea"], "g.-", label="South Korea")
plt.plot(gas.Year, gas.France, "y.-", label="France")

plt.xlabel("Yıl")
plt.ylabel("Dolar")

plt.legend()
plt.show()
